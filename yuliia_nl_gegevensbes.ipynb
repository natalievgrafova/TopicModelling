# %%
import spacy
import pandas as pd
import nl_core_news_lg
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()# Visualise inside a notebook

# %%
df = pd.read_csv('500_nl_gegevensbes.csv')

# %%
df.head(5)
# Out:
#                         _id  \
# 0  5ec806708e00d85b900a3fd7
# 1  5ec806757db77e056c19b83c
# 2  5ec80677ac7298b94a3cf469
# 3  5ec8e7cc51562f74bacea418
# 4  5ecb6efcc4e7799c699b07d8
#
#                                                  url  \
# 0  https://www.nieuwsblad.be/cnt/dmf20200518_0496...
# 1  https://www.standaard.be/cnt/dmf20200518_04964571
# 2              https://www.tijd.be/r/t/1/id/10227928
# 3  https://www.hln.be/geld/datingsite-twoo-krijgt...
# 4  https://www.nieuwsblad.be/cnt/dmf20200525_0497...
#
#                        date  \
# 0  2020-05-18T19:23:33.000Z
# 1  2020-05-18T20:14:00.000Z
# 2  2020-05-18T19:35:19.000Z
# 3  2020-05-22T15:13:15.556Z
# 4  2020-05-25T04:56:20.000Z
#
#                                                 text  \
# 0  Proximus krijgt van de Gegevensbeschermingsaut...
# 1  Proximus krijgt van de Gegevensbeschermingsaut...
# 2  De Belgische privacywaakhond heeft Proximus de...
# 3  Datingsite Twoo krijgt boete van 50.000 euro n...
# 4  De inspectiedienst van de Gegevensbeschermings...
#
#                                                title
# 0  Proximus krijgt recordboete van 50.000 euro vo...
# 1  Proximus krijgt recordboete van 50.000 euro vo...
# 2  Proximus moet privacyboete van 50.000 euro oph...
# 3  Datingsite Twoo krijgt boete van 50.000 euro n...
# 4  Privacywaakhond legde al 59 sancties op, maar ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   _id     428 non-null    object
#  1   url     428 non-null    object
#  2   date    428 non-null    object
#  3   text    428 non-null    object
#  4   title   428 non-null    object
# dtypes: object(5)
# memory usage: 16.8+ KB

# %%
df_drop = df.drop(columns = ['_id','url', 'date', 'title'])

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    428 non-null    object
# dtypes: object(1)
# memory usage: 3.5+ KB

# %%
df_drop['text'] = df_drop['text'].astype(str)

# %%
# SpaCy model:
nlp = nl_core_news_lg.load()
# Tags I want to remove from the text
removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']

tokens = []
for summary in nlp.pipe(df_drop['text']):
   proj_tok = [token.lemma_.lower() for token in summary if token.pos_ not in removal and not token.is_stop and token.is_alpha]
   tokens.append(proj_tok)

# %%
df_drop['tokens'] = tokens
df_drop['tokens']
# Out:
# 0      [proximus, krijgen, gegevensbeschermingsautori...
# 1      [proximus, krijgen, gegevensbeschermingsautori...
# 2      [belgisch, privacywaakhond, proximus, hoog, bo...
# 3      [datingsite, twoo, krijgen, boete, euro, schen...
# 4      [inspectiedienst, gegevensbeschermingsautorite...
#                              ...
# 423    [socialistisch, vakbond, nationaal, bank, klac...
# 424    [omgaan, informatie, internet, veranderen, job...
# 425    [gaan, temu, chinees, bedrijf, vallen, chinees...
# 426    [david, stevens, zijn, voorzitter, gegevensbes...
# 427    [online, seksueel, misbruikbeelid, kind, rappo...
# Name: tokens, Length: 428, dtype: object

# %% [markdown]
# Create dictionary and corpus

# %%
# I will apply the Dictionary Object from Gensim, which maps each word to their unique ID:
dictionary = Dictionary(df_drop['tokens'])

# %%
print(dictionary)
# Out:
# Dictionary<9828 unique tokens: ['aankondigen', 'aanpassen', 'basis', 'bedrijf', 'belangenconflict']...>

# %%
#some of the IDs assigned to the tokens
print(dictionary.token2id)
# Out:
# {'aankondigen': 0, 'aanpassen': 1, 'basis': 2, 'bedrijf': 3, 'belangenconflict': 4, 'bericht': 5, 'beroep': 6, 'beslissen': 7, 'beslissing': 8, 'besluiten': 9, 'blijven': 10, 'boete': 11, 'data': 12, 'directeur': 13, 'dpo': 14, 'echo': 15, 'euro': 16, 'fenaux': 17, 'functie': 18, 'gaan': 19, 'gba': 20, 'gegevensbeschermingsautoriteit': 21, 'geschillenkamer': 22, 'geval': 23, 'gids': 24, 'goed': 25, 'handelen': 26, 'haroun': 27, 'hielke': 28, 'hijmans': 29, 'implementatie': 30, 'krijgen': 31, 'l': 32, 'lezen': 33, 'maand': 34, 'maandagavond': 35, 'marktenhof': 36, 'motivering': 37, 'neemt': 38, 'niveau': 39, 'overeenstemming': 40, 'overtuigen': 41, 'persoon': 42, 'procedure': 43, 'proximus': 44, 'raadgever': 45, 'reageren': 46, 'recordboete': 47, 'respecteren': 48, 'vastleggen': 49, 'verantwoordelijk': 50, 'verondersteld': 51, 'voldoen': 52, 'woordvoerder': 53, 'zeggen': 54, 'ïmplementeren': 55, 'melden': 56, 'adviseur': 57, 'bedragen': 58, 'belgisch': 59, 'belgië': 60, 'betalen': 61, 'bijzonder': 62, 'conclusie': 63, 'databescherming': 64, 'datum': 65, 'doen': 66, 'euorpees': 67, 'europees': 68, 'gdpr': 69, 'geschillencommissie': 70, 'hoog': 71, 'instelling': 72, 'jaar': 73, 'jaaromzet': 74, 'komen': 75, 'kracht': 76, 'kwestie': 77, 'land': 78, 'leggen': 79, 'mild': 80, 'miljoen': 81, 'naleven': 82, 'naleving': 83, 'nemen': 84, 'omzet': 85, 'opleggen': 86, 'optreden': 87, 'principe': 88, 'privacymanager': 89, 'privacywaakhond': 90, 'procent': 91, 'record': 92, 'regel': 93, 'rol': 94, 'spelen': 95, 'straf': 96, 'strikt': 97, 'telecomgroep': 98, 'toezien': 99, 'vergelijking': 100, 'verplichten': 101, 'verzamelen': 102, 'voorzitster': 103, 'zwaar': 104, 'aangevinkt': 105, 'aangevinkte': 106, 'absoluut': 107, 'akkoord': 108, 'algemeen': 109, 'april': 110, 'avg': 111, 'bekomen': 112, 'belga': 113, 'bescherming': 114, 'beslag': 115, 'bestaan': 116, 'ceo': 117, 'contact': 118, 'contactperson': 119, 'datingsite': 120, 'document': 121, 'doeleinde': 122, 'duidelijk': 123, 'evenaart': 124, 'facebook': 125, 'functies': 126, 'gebruiken': 127, 'gebruiker': 128, 'gegevensberschermingsautoriteit': 129, 'gegevensbescherming': 130, 'geld': 131, 'gent': 132, 'gezondheidsgegeven': 133, 'grondig': 134, 'groot': 135, 'hield': 136, 'hoofdkantoor': 137, 'hospitalisatieverzekering': 138, 'industrie': 139, 'internetdienst': 140, 'joost': 141, 'juli': 142, 'kader': 143, 'kort': 144, 'legde': 145, 'lid': 146, 'luiden': 147, 'maatschappij': 148, 'mei': 149, 'mens': 150, 'naam': 151, 'nieuw': 152, 'nodigen': 153, 'noemen': 154, 'oneens': 155, 'onlineplatform': 156, 'ontmoeten': 157, 'oog': 158, 'oordeelde': 159, 'ophoesten': 160, 'opslaan': 161, 'persoonsgegeven': 162, 'platform': 163, 'praktijk': 164, 'privacyregel': 165, 'reactie': 166, 'recordbedrag': 167, 'rekening': 168, 'roelandts': 169, 'schenden': 170, 'schending': 171, 'smartphone': 172, 'stopgezeten': 173, 'streng': 174, 'strijd': 175, 'sturen': 176, 'telecombedrijf': 177, 'telefoonnummer': 178, 'tijd': 179, 'toestemming': 180, 'toestemmingsvereisten': 181, 'toevoegen': 182, 'transparantie': 183, 'twoo': 184, 'uitdrukkelijk': 185, 'uitnodigen': 186, 'uitnodiging': 187, 'uitnodigingsmail': 188, 'uploaden': 189, 'vak': 190, 'verkrijgen': 191, 'verordening': 192, 'versturen': 193, 'verwerken': 194, 'verzekeraar': 195, 'vestigen': 196, 'vinden': 197, 'voldeen': 198, 'volgen': 199, 'volledig': 200, 'voorbeeld': 201, 'vorig': 202, 'vriend': 203, 'vrijdag': 204, 'week': 205, 'zaak': 206, 'aanleiding': 207, 'aanpak': 208, 'actief': 209, 'advies': 210, 'bemiddelingsverzoeken': 211, 'burger': 212, 'dateren': 213, 'dkv': 214, 'doel': 215, 'doeltreffender': 216, 'duurzaam': 217, 'exact': 218, 'eynde': 219, 'formuleren': 220, 'gebruik': 221, 'gegevenslekken': 222, 'globaal': 223, 'grootschalig': 224, 'heden': 225, 'hoofddoel': 226, 'informatievrag': 227, 'initiatief': 228, 'inspectie': 229, 'inspectiebeleid': 230, 'inspectiedienst': 231, 'instaan': 232, 'klacht': 233, 'klinken': 234, 'leiden': 235, 'maandag': ...

# %%
#filter out low-frequency and high-frequency tokens, also limit the vocabulary to a max of 1000 words
dictionary.filter_extremes(no_below=5, no_above=0.5, keep_n=1000)

# %%
#construct the corpus using the dictionary from above and the doc2bow function.
#The function doc2bow() simply counts the number of occurrences of each distinct word,
#converts the word to its integer word id and returns the result as a sparse vector
corpus = [dictionary.doc2bow(doc) for doc in df_drop['tokens']]

# %% [markdown]
# Model building

# %%
#train the unsupervised machine learning model on the data. 
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=50, num_topics=10, workers = 4, passes=10)

# %% [markdown]
# Calculating the coherence score using C_umass

# %%
topics = []
score = []
for i in range(1,20,1):
   lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=i, workers = 4, passes=10, random_state=100)
   cm = CoherenceModel(model=lda_model, corpus=corpus, dictionary=dictionary, coherence='u_mass')
   topics.append(i)
   score.append(cm.get_coherence())
_=plt.plot(topics, score)
_=plt.xlabel('Number of Topics')
_=plt.ylabel('Coherence Score')
plt.show()

# %% [markdown]
# Calculating the coherence score using C_v

# %%
topics = []
score = []
for i in range(1,20,1):
   lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=i, workers = 4, passes=10, random_state=100)
   cm = CoherenceModel(model=lda_model, texts = df_drop['tokens'], corpus=corpus, dictionary=dictionary, coherence='c_v')
   topics.append(i)
   score.append(cm.get_coherence())
_=plt.plot(topics, score)
_=plt.xlabel('Number of Topics')
_=plt.ylabel('Coherence Score')
plt.show()

# %% [markdown]
# When looking at the coherence using the C_umass or C_v algorithm, the best is usually the max. Looking at the graphs I choose to go with 6 topics.

# %% [markdown]
# Optimal model

# %%
lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=5, workers = 4, passes=100)

# %% [markdown]
# Print and visualize topics

# %%
lda_model.print_topics(-1)
# Out:
# [(0,
#   '0.031*"gba" + 0.015*"robben" + 0.012*"commissie" + 0.011*"lid" + 0.011*"stevens" + 0.011*"parlement" + 0.010*"gaan" + 0.010*"zeggen" + 0.009*"voorzitter" + 0.007*"jaar"'),
#  (1,
#   '0.015*"zeggen" + 0.014*"gaan" + 0.011*"gebruiken" + 0.010*"maken" + 0.010*"jaar" + 0.009*"krijgen" + 0.008*"mens" + 0.008*"komen" + 0.007*"app" + 0.007*"minister"'),
#  (2,
#   '0.014*"privacy" + 0.011*"burger" + 0.010*"maken" + 0.009*"digitaal" + 0.009*"mens" + 0.009*"gaan" + 0.009*"gegeven" + 0.008*"groot" + 0.008*"laten" + 0.008*"komen"'),
#  (3,
#   '0.031*"bedrijf" + 0.030*"europees" + 0.022*"boete" + 0.017*"gebruiker" + 0.017*"euro" + 0.015*"gegeven" + 0.014*"facebook" + 0.013*"google" + 0.013*"miljoen" + 0.012*"europa"'),
#  (4,
#   '0.049*"cst" + 0.036*"brussels" + 0.025*"gebruik" + 0.022*"parlement" + 0.022*"regering" + 0.020*"sector" + 0.019*"samenwerkingsakkoord" + 0.017*"vlaams" + 0.016*"persoon" + 0.014*"gewest"')]

# %% [markdown]
# Where does a text belong to

# %%
df['text'][0]
# Out:
# 'Proximus krijgt van de Gegevensbeschermingsautoriteit (GBA) een recordboete van 50.000 euro voor een belangenconflict bij zijn Data Protection Officer (DPO), zo bericht L’Echo maandagavond. De DPO is de persoon die binnen het bedrijf verantwoordelijk is voor de goede implementatie van de GDPR-richtlijn.\\n\\n“De DPO wordt verondersteld een gids te zijn in deze procedures. Je kan niet de raadgever zijn én degene die de beslissing neemt zoals bij Proximus het geval was”, zegt Hielke Hijmans, de directeur van de geschillenkamer van de GBA.\\n\\nProximus heeft een maand om in beroep te gaan bij het Marktenhof, maar heeft aangekondigd de beslissing te zullen respecteren. “Op basis van het lezen van de motivering blijven we ervan overtuigd dat wat we hebben geïmplementeerd op het niveau van onze DPO voldeed aan de GDPR-vereisten. De geschillenkamer van de GBA heeft er anders over beslist en besloot een boete op te leggen aan Proximus. We zullen handelen in overeenstemming met de beslissing en de functie van onze DPO aanpassen”, reageerde woordvoerder Haroun Fenaux.'

# %%
lda_model[corpus][0]
# Out:
# [(0, 0.8073243), (3, 0.17965385)]

# %%
#According to our LDA model, the above text belongs to Topic 0 and 4.
#The article is 80% belonging to topic 4 (index 3) and 16% belonging to topic 0 (index 1).

# %% [markdown]
# Visualization

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el
"ethisch", "beschikbaar", "samenwerking", "misbruik", "doorgeven", "werknemer", "lijken", "vertrouwen", "lezen", "burger", "ontwikkeling", "digitaal", "datum", "privacy", "databank", "opnemen", "dergelijk", "belangrijk", "groot", "werken", "risico", "laten", "mens", "informatie", "nieuw", "houden", "maken", "komen", "overheid", "toegang", "gegeven", "gaan", "regering", "maatregel", "goed", "blijven", "nodig", "advies", "zeggen", "robben", "stevens", "voorzitter", "brief", "contactonderzoek", "onafhankelijkheid", "geschillenkamer", "comit\u00e9", "kenniscentrum", "jaspar", "grondrecht", "soir", "kruispuntbank", "belangenconflict", "hijmans", "directiecomit\u00e9", "sciensano", "besmet", "topambtenaar", "audit", "orgaan", "alexandra", "hielke", "ontslag", "belangenvermenging", "drijven", "frank", "precedent", "integriteit", "functioneren", "lid", "david", "gba", "le", "directeur", "commissie", "extern", "onafhankelijk", "functie", "politiek", "hoorzitting", "parlement", "vorig", "belgi\u00eb", "gaan", "zeggen", "klacht", "justitie", "verschillend", "jaar", "staan", "nemen", "europees", "stellen", "gegeven", "overheid", "maken", "belgisch", "krijgen", "samenwerkingsakkoord", "vaccinatiegraad", "gemeenschapscommissie", "agora", "lootens", "uitvoeringsordonnantie", "vervoort", "dancing", "overlegcomit\u00e9", "congres", "recreatief", "cultureel", "feestelijk", "rudi", "discotheek", "residentieel", "keurde", "fitnesscentrum", "legitimiteit", "benadruken", "opkrikken", "modaliteit", "donderdagmiddag", "sportclub", "stemden", "maron", "onthieldn", "opdelen", "alain", "bianca", "plenair", "pvda", "gewest", "cst", "brussels", "goedkeuren", "sector", "vergadering", "gebruik", "gemeenschappelijk", "parlement", "uitbreiding", "regering", "vlaams", "aankondigen", "persoon", "belang", "woensdag", "tekst", "gebruiken", "aantal", "controleren", "stellen", "safe", "covid", "facebook", "iers", "meta", "bankrekening", "instagram", "boete", "dpc", "mededeling", "inzage", "vs", "toezichthouder", "financi\u00ebn", "luxemburg", "hoofdkantoor", "fod", "miljoen", "google", "eisen", "business", "ierland", "moederbedrijf", "eu", "miljard", "vestigen", ...

# %%
#path = os.path.join('.results')

# %%
#with open(path, 'wb') as f:
    #pickle.dump(LDAvis,f)

#with open(path, 'rb') as f:
    #LDAvis = pickle.load(f)

#pyLDAvis.save_html(LDAvis, './results' + '_spacy' + '.html')

# %%
# Load the SpaCy model
nlp = spacy.load('nl_core_news_lg')

# Tags I want to remove from the text
removal = ['ADV', 'PRON', 'CCONJ', 'PUNCT', 'PART', 'DET', 'ADP', 'SPACE', 'NUM', 'SYM', 'AUX', 'SCONJ', 'INTJ']

# Words I want to remove from the tokens
remove_words = ['al', 'als', 'een', 'om', 'het', 'de', 'dat', 'nog', 'ook']

tokens = []

for summary in nlp.pipe(df_drop['text']):
    proj_tok = [token.lemma_.lower() for token in summary if token.pos_ not in removal and not token.is_stop and token.is_alpha
                and token.text.lower() not in remove_words]
    tokens.append(proj_tok)
