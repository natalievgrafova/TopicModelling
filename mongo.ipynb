# %% [markdown]
# Connecting to MondoDB

# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
from pprint import pprint

# %%
myclient = MongoClient("mongodb://bouman:80um4N!@ec2-15-188-255-64.eu-west-3.compute.amazonaws.com:27017/")

# %%
print(myclient.list_database_names())
# Out:
# ['bouman_datatank', 'media_analysis']

# %%
datatank = myclient.bouman_datatank

# %%
print(datatank.list_collection_names)
# Out:
# <bound method Database.list_collection_names of Database(MongoClient(host=['ec2-15-188-255-64.eu-west-3.compute.amazonaws.com:27017'], document_class=dict, tz_aware=False, connect=True), 'bouman_datatank')>

# %%
pprint(datatank)
# Out:
# Database(MongoClient(host=['ec2-15-188-255-64.eu-west-3.compute.amazonaws.com:27017'], document_class=dict, tz_aware=False, connect=True), 'bouman_datatank')

# %%
mydb = myclient.media_analysis
#db = myclient['media_analysis']

# %%
print(mydb.list_collection_names())
# Out:
# ['articles']

# %%
mycol = mydb['articles']

# %%
pprint(mycol.find_one())
# Out:
# {'_id': ObjectId('5ec760320e5c92500d004aec'),
#  'date': datetime.datetime(2020, 5, 22, 4, 49, 17),
#  'meta': {'feedparser': {'publication_date': datetime.datetime(2020, 5, 22, 4, 49, 17),
#                          'summary': 'Jamal Khashoggi, critique du régime '
#                                     'saoudien après en avoir été proche, a été '
#                                     'assassiné et son corps découpé en '
#                                     'morceaux le 2 octobre 2018',
#                          'title': 'La famille du journaliste saoudien tué dans '
#                                   'le consul d’Arabie saoudite à Istanbul '
#                                   '«pardonne» aux assassins'},
#           'newspaper3k': {'authors': [],
#                           'summary': '',
#                           'top_image': 'https://plus.lesoir.be/sites/default/files/dpistyles_v2/ena_16_9_extra_big/2020/05/22/node_302284/27555231/public/2020/05/22/B9723524265Z.1_20200522064917_000+GBHG20GPF.1-0.jpg?itok=KHWta-0l1590122967'},
#           'source': {'country': 'BE',
#                      'feed_title': 'La une',
#                      'feed_url': 'https://plus.lesoir.be/rss/81853/cible_principale_gratuit',
#                      'language': 'fr',
#                      'name': 'lesoir.be'}},
#  'text': 'Jamal Khashoggi, critique du régime saoudien après en avoir été '
#          'proche, a été assassiné et son corps découpé en morceaux le 2 '
#          'octobre 2018\n'
#          '\n'
#          'Les enfants de Jamal Khashoggi, journaliste saoudien assassiné en '
#          'octobre 2018 dans le consulat d’Arabie saoudite à Istanbul, ont '
#          'annoncé vendredi qu’ils pardonnaient aux tueurs de leur père.\n'
#          '\n'
#          '« Nous, les fils du martyr Jamal Khashoggi, annonçons que nous '
#          'pardonnons à ceux qui ont tué notre père », a écrit sur Twitter '
#          'Salah Khashoggi, fils de l’ancien journaliste du Washington Post.\n'
#          '\n'
#          'Un meurtre odieux\n'
#          '\n'
#          'Jamal Khashoggi, critique du régime saoudien après en avoir été '
#          'proche, a été assassiné et son corps découpé en morceaux le 2 '
#          'octobre 2018 dans le consulat d’Arabie saoudite à Istanbul où il '
#          's’était rendu pour récupérer un document.',
#  'textrazor_response': {'ok': True,
#                         'response': {'coarseTopics': [{'id': 0,
#                                                        'label': 'Politics',
#                                                        'score': 1,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Politics'},
#                                                       {'id': 1,
#                                                        'label': 'Violence',
#                                                        'score': 0.9795,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Violence'},
#                                                       {'id': 2,
#                                                        'label': 'Culture',
#                                                        'score': 0.7495,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Culture'},
#                                                       {'id': 3,
#                                                        'label': 'Law',
#                                                        'score': 0.3354,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Law'},
#                                                       {'id': 4,
#                                                        'label': 'Arts',
#                                                        'score': 0.305,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Arts'},
#                                                       {'id': 5,
#                                                        'label': 'Belief',
#                                                        'score': 0.2447,
#                                                        'wikiLink': 'http://en.wikipedia.org/Category:Belief'}],
#                                      'entities': [{'confidenceScore': 16.1,
#                                                    'endingPos': 475,
#                                                    'entityEnglishId': 'Jamal '
#                                                                       'Khashoggi',
#                                                    'entityId': 'Jamal '
#                                                                'Khashoggi',
#                                                    'freebaseId': '',
#                                                    'freebaseTypes': ['/people/person'],
#                                                    'id': 0,
#                                                    'matchedText': 'Khashoggi',
#                                                    'matchingTokens': [89],
#                                                    'relevanceScore': 1,
#                                                    'startingPos': 466,
#                                                    'type': ['Agent', 'Person'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Jamal_Khashoggi',
#                                                    'wikidataId': 'Q1262052'},
#                                                   {'confidenceScore': 16.1,
#                                                    'endingPos': 375,
#                                                    'entityEnglishId': 'Jamal '
#                                                                       'Khashoggi',
#                                                    'entityId': 'Jamal '
#                                                                'Khashoggi',
#                                                    'freebaseId': '',
#                                                    'freebaseTypes': ['/people/person'],
#                                                    'id': 1,
#                                                    'matchedText': 'Jamal '
#                                                                   'Khashoggi',
#                                                    'matchingTokens': [68, 69],
#                                                    'relevanceScore': 1,
#                                                    'startingPos': 360,
#                                                    'type': ['Agent', 'Person'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Jamal_Khashoggi',
#                                                    'wikidataId': 'Q1262052'},
#                                                   {'confidenceScore': 16.1,
#                                                    'endingPos': 170,
#                                                    'entityEnglishId': 'Jamal '
#                                                                       'Khashoggi',
#                                                    'entityId': 'Jamal '
#                                                                'Khashoggi',
#                                                    'freebaseId': '',
#                                                    'freebaseTypes': ['/people/person'],
#                                                    'id': 2,
#                                                    'matchedText': 'Jamal '
#                                                                   'Khashoggi',
#                                                    'matchingTokens': [30, 31],
#                                                    'relevanceScore': 1,
#                                                    'startingPos': 155,
#                                                    'type': ['Agent', 'Person'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Jamal_Khashoggi',
#                                                    'wikidataId': 'Q1262052'},
#                                                   {'confidenceScore': 16.1,
#                                                    'endingPos': 561,
#                                                    'entityEnglishId': 'Jamal '
#                                                                       'Khashoggi',
#                                                    'entityId': 'Jamal '
#                                                                'Khashoggi',
#                                                    'freebaseId': '',
#                                                    'freebaseTypes': ['/people/person'],
#                                                    'id': 3,
#                                                    'matchedText': 'Jamal '
#                                                                   'Khashoggi',
#                                                    'matchingTokens': [104, 105],
#                                                    'relevanceScore': 1,
#                                                    'startingPos': 546,
#                                                    'type': ['Agent', 'Person'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Jamal_Khashoggi',
#                                                    'wikidataId': 'Q1262052'},
#                                                   {'confidenceScore': 7.824,
#                                                    'endingPos': 730,
#                                                    'entityEnglishId': 'Istanbul',
#                                                    'entityId': 'Istanbul',
#                                                    'freebaseId': '/m/09949m',
#                                                    'freebaseTypes': ['/location/capital_of_administrative_division',
#                                                                      '/location/administrative_division',
#                                                                      '/book/book_subject',
#                                                                      '/location/place_with_neighborhoods',
#                                                                      '/tv/tv_location',
#                                                                      '/olympics/olympic_bidding_city',
#                                                                      '/location/dated_location',
#                                                                      '/location/statistical_region',
#                                                                      '/sports/sports_team_location',
#                                                                      '/film/film_location',
#                                                                      '/protected_sites/listed_site',
#                                                                      '/travel/travel_destination',
#                                                                      '/location/location',
#                                                                      '/fictional_universe/fictional_setting',
#                                                                      '/location/citytown',
#                                                                      '/periodicals/newspaper_circulation_area'],
#                                                    'id': 4,
#                                                    'matchedText': 'Istanbul',
#                                                    'matchingTokens': [137],
#                                                    'relevanceScore': 0.062,
#                                                    'startingPos': 722,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Settlement',
#                                                             'City'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Istanbul',
#                                                    'wikidataId': 'Q406'},
#                                                   {'confidenceScore': 20.2,
#                                                    'endingPos': 192,
#                                                    'entityEnglishId': 'Saudi '
#                                                                       'Arabia',
#                                                    'entityId': 'Arabie '
#                                                                'saoudite',
#                                                    'freebaseId': '/m/01z215',
#                                                    'freebaseTypes': ['/government/government',
#                                                                      '/business/employer',
#                                                                      '/organization/organization_founder',
#                                                                      '/business/business_location',
#                                                                      '/location/location',
#                                                                      '/government/governmental_jurisdiction',
#                                                                      '/periodicals/newspaper_circulation_area',
#                                                                      '/location/dated_location',
#                                                                      '/organization/organization_scope',
#                                                                      '/olympics/olympic_participating_country',
#                                                                      '/military/military_post',
#                                                                      '/location/country',
#                                                                      '/location/statistical_region',
#                                                                      '/book/book_subject',
#                                                                      '/royalty/kingdom',
#                                                                      '/military/military_combatant',
#                                                                      '/sports/sports_team_location',
#                                                                      '/organization/organization_member',
#                                                                      '/symbols/flag_referent',
#                                                                      '/symbols/namesake'],
#                                                    'id': 5,
#                                                    'matchedText': 'saoudien',
#                                                    'matchingTokens': [34],
#                                                    'relevanceScore': 0.3897,
#                                                    'startingPos': 184,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Country'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Arabie_saoudite',
#                                                    'wikidataId': 'Q851'},
#                                                   {'confidenceScore': 20.2,
#                                                    'endingPos': 590,
#                                                    'entityEnglishId': 'Saudi '
#                                                                       'Arabia',
#                                                    'entityId': 'Arabie '
#                                                                'saoudite',
#                                                    'freebaseId': '/m/01z215',
#                                                    'freebaseTypes': ['/government/government',
#                                                                      '/business/employer',
#                                                                      '/organization/organization_founder',
#                                                                      '/business/business_location',
#                                                                      '/location/location',
#                                                                      '/government/governmental_jurisdiction',
#                                                                      '/periodicals/newspaper_circulation_area',
#                                                                      '/location/dated_location',
#                                                                      '/organization/organization_scope',
#                                                                      '/olympics/olympic_participating_country',
#                                                                      '/military/military_post',
#                                                                      '/location/country',
#                                                                      '/location/statistical_region',
#                                                                      '/book/book_subject',
#                                                                      '/royalty/kingdom',
#                                                                      '/military/military_combatant',
#                                                                      '/sports/sports_team_location',
#                                                                      '/organization/organization_member',
#                                                                      '/symbols/flag_referent',
#                                                                      '/symbols/namesake'],
#                                                    'id': 6,
#                                                    'matchedText': 'saoudien',
#                                                    'matchingTokens': [110],
#                                                    'relevanceScore': 0.3897,
#                                                    'startingPos': 582,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Country'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Arabie_saoudite',
#                                                    'wikidataId': 'Q851'},
#                                                   {'confidenceScore': 23.74,
#                                                    'endingPos': 719,
#                                                    'entityEnglishId': 'Saudi '
#                                                                       'Arabia',
#                                                    'entityId': 'Arabie '
#                                                                'saoudite',
#                                                    'freebaseId': '/m/01z215',
#                                                    'freebaseTypes': ['/government/government',
#                                                                      '/business/employer',
#                                                                      '/organization/organization_founder',
#                                                                      '/business/business_location',
#                                                                      '/location/location',
#                                                                      '/government/governmental_jurisdiction',
#                                                                      '/periodicals/newspaper_circulation_area',
#                                                                      '/location/dated_location',
#                                                                      '/organization/organization_scope',
#                                                                      '/olympics/olympic_participating_country',
#                                                                      '/military/military_post',
#                                                                      '/location/country',
#                                                                      '/location/statistical_region',
#                                                                      '/book/book_subject',
#                                                                      '/royalty/kingdom',
#                                                                      '/military/military_combatant',
#                                                                      '/sports/sports_team_location',
#                                                                      '/organization/organization_member',
#                                                                      '/symbols/flag_referent',
#                                                                      '/symbols/namesake'],
#                                                    'id': 7,
#                                                    'matchedText': 'Arabie '
#                                                                   'saoudite',
#                                                    'matchingTokens': [134, 135],
#                                                    'relevanceScore': 0.3095,
#                                                    'startingPos': 704,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Country'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Arabie_saoudite',
#                                                    'wikidataId': 'Q851'},
#                                                   {'confidenceScore': 1.036,
#                                                    'endingPos': 701,
#                                                    'entityEnglishId': 'French '
#                                                                       'Consulate',
#                                                    'entityId': 'Consulat '
#                                                                '(histoire de '
#                                                                'France)',
#                                                    'freebaseId': '/m/01frd1',
#                                                    'freebaseTypes': ['/book/book_subject',
#                                                                      '/government/form_of_government',
#                                                                      '/time/event'],
#                                                    'id': 8,
#                                                    'matchedText': 'consulat',
#                                                    'matchingTokens': [132],
#                                                    'relevanceScore': 0.1457,
#                                                    'startingPos': 693,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Territory',
#                                                             'OldTerritory'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Consulat_(histoire_de_France)',
#                                                    'wikidataId': 'Q877619'},
#                                                   {'confidenceScore': 1.078,
#                                                    'endingPos': 679,
#                                                    'entityEnglishId': 'October '
#                                                                       '2',
#                                                    'entityId': '2 octobre',
#                                                    'freebaseId': '/m/05n0s',
#                                                    'freebaseTypes': ['/location/location',
#                                                                      '/time/day_of_year'],
#                                                    'id': 9,
#                                                    'matchedText': '2 octobre',
#                                                    'matchingTokens': [127, 128],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 670,
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/2_octobre',
#                                                    'wikidataId': 'Q2932'},
#                                                   {'confidenceScore': 1.078,
#                                                    'endingPos': 133,
#                                                    'entityEnglishId': 'October '
#                                                                       '2',
#                                                    'entityId': '2 octobre',
#                                                    'freebaseId': '/m/05n0s',
#                                                    'freebaseTypes': ['/location/location',
#                                                                      '/time/day_of_year'],
#                                                    'id': 10,
#                                                    'matchedText': '2 octobre',
#                                                    'matchingTokens': [23, 24],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 124,
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/2_octobre',
#                                                    'wikidataId': 'Q2932'},
#                                                   {'confidenceScore': 1.036,
#                                                    'endingPos': 235,
#                                                    'entityEnglishId': 'French '
#                                                                       'Consulate',
#                                                    'entityId': 'Consulat '
#                                                                '(histoire de '
#                                                                'France)',
#                                                    'freebaseId': '/m/01frd1',
#                                                    'freebaseTypes': ['/book/book_subject',
#                                                                      '/government/form_of_government',
#                                                                      '/time/event'],
#                                                    'id': 11,
#                                                    'matchedText': 'consulat',
#                                                    'matchingTokens': [41],
#                                                    'relevanceScore': 0.1457,
#                                                    'startingPos': 227,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Territory',
#                                                             'OldTerritory'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Consulat_(histoire_de_France)',
#                                                    'wikidataId': 'Q877619'},
#                                                   {'confidenceScore': 1.705,
#                                                    'endingPos': 519,
#                                                    'entityEnglishId': 'Washington, '
#                                                                       'D.C.',
#                                                    'entityId': 'Washington '
#                                                                '(district de '
#                                                                'Columbia)',
#                                                    'freebaseId': '/m/0rh6k',
#                                                    'freebaseTypes': ['/organization/organization_scope',
#                                                                      '/visual_art/art_subject',
#                                                                      '/location/citytown',
#                                                                      '/location/hud_county_place',
#                                                                      '/location/hud_foreclosure_area',
#                                                                      '/business/employer',
#                                                                      '/location/statistical_region',
#                                                                      '/sports/sports_team_location',
#                                                                      '/periodicals/newspaper_circulation_area',
#                                                                      '/location/us_federal_district',
#                                                                      '/projects/project_focus',
#                                                                      '/fictional_universe/fictional_setting',
#                                                                      '/travel/travel_destination',
#                                                                      '/location/administrative_division',
#                                                                      '/location/place_with_neighborhoods',
#                                                                      '/location/metropolitan_area_anchor',
#                                                                      '/location/dated_location',
#                                                                      '/government/governmental_jurisdiction',
#                                                                      '/military/military_unit_place_of_origin',
#                                                                      '/film/film_location',
#                                                                      '/military/military_post',
#                                                                      '/location/location',
#                                                                      '/book/book_subject',
#                                                                      '/symbols/namesake'],
#                                                    'id': 12,
#                                                    'matchedText': 'Washington',
#                                                    'matchingTokens': [97],
#                                                    'relevanceScore': 0.06681,
#                                                    'startingPos': 509,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Settlement',
#                                                             'City'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Washington_(district_de_Columbia)',
#                                                    'wikidataId': 'Q61'},
#                                                   {'confidenceScore': 0.5,
#                                                    'endingPos': 125,
#                                                    'entityEnglishId': '',
#                                                    'entityId': '2',
#                                                    'id': 13,
#                                                    'matchedText': '2',
#                                                    'matchingTokens': [23],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 124,
#                                                    'type': ['Number'],
#                                                    'unit': 'Number',
#                                                    'wikiLink': ''},
#                                                   {'confidenceScore': 0.5,
#                                                    'endingPos': 671,
#                                                    'entityEnglishId': '',
#                                                    'entityId': '2',
#                                                    'id': 14,
#                                                    'matchedText': '2',
#                                                    'matchingTokens': [127],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 670,
#                                                    'type': ['Number'],
#                                                    'unit': 'Number',
#                                                    'wikiLink': ''},
#                                                   {'confidenceScore': 0.5,
#                                                    'endingPos': 218,
#                                                    'entityEnglishId': '',
#                                                    'entityId': '2018',
#                                                    'id': 15,
#                                                    'matchedText': '2018',
#                                                    'matchingTokens': [38],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 214,
#                                                    'type': ['Number'],
#                                                    'unit': 'Number',
#                                                    'wikiLink': ''},
#                                                   {'confidenceScore': 0.5,
#                                                    'endingPos': 684,
#                                                    'entityEnglishId': '',
#                                                    'entityId': '2018',
#                                                    'id': 16,
#                                                    'matchedText': '2018',
#                                                    'matchingTokens': [129],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 680,
#                                                    'type': ['Number'],
#                                                    'unit': 'Number',
#                                                    'wikiLink': ''},
#                                                   {'confidenceScore': 0.5,
#                                                    'endingPos': 138,
#                                                    'entityEnglishId': '',
#                                                    'entityId': '2018',
#                                                    'id': 17,
#                                                    'matchedText': '2018',
#                                                    'matchingTokens': [25],
#                                                    'relevanceScore': 0,
#                                                    'startingPos': 134,
#                                                    'type': ['Number'],
#                                                    'unit': 'Number',
#                                                    'wikiLink': ''},
#                                                   {'confidenceScore': 7.824,
#                                                    'endingPos': 264,
#                                                    'entityEnglishId': 'Istanbul',
#                                                    'entityId': 'Istanbul',
#                                                    'freebaseId': '/m/09949m',
#                                                    'freebaseTypes': ['/location/capital_of_administrative_division',
#                                                                      '/location/administrative_division',
#                                                                      '/book/book_subject',
#                                                                      '/location/place_with_neighborhoods',
#                                                                      '/tv/tv_location',
#                                                                      '/olympics/olympic_bidding_city',
#                                                                      '/location/dated_location',
#                                                                      '/location/statistical_region',
#                                                                      '/sports/sports_team_location',
#                                                                      '/film/film_location',
#                                                                      '/protected_sites/listed_site',
#                                                                      '/travel/travel_destination',
#                                                                      '/location/location',
#                                                                      '/fictional_universe/fictional_setting',
#                                                                      '/location/citytown',
#                                                                      '/periodicals/newspaper_circulation_area'],
#                                                    'id': 18,
#                                                    'matchedText': 'Istanbul',
#                                                    'matchingTokens': [46],
#                                                    'relevanceScore': 0.062,
#                                                    'startingPos': 256,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Settlement',
#                                                             'City'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Istanbul',
#                                                    'wikidataId': 'Q406'},
#                                                   {'confidenceScore': 16.1,
#                                                    'endingPos': 15,
#                                                    'entityEnglishId': 'Jamal '
#                                                                       'Khashoggi',
#                                                    'entityId': 'Jamal '
#                                                                'Khashoggi',
#                                                    'freebaseId': '',
#                                                    'freebaseTypes': ['/people/person'],
#                                                    'id': 19,
#                                                    'matchedText': 'Jamal '
#                                                                   'Khashoggi',
#                                                    'matchingTokens': [0, 1],
#                                                    'relevanceScore': 1,
#                                                    'startingPos': 0,
#                                                    'type': ['Agent', 'Person'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Jamal_Khashoggi',
#                                                    'wikidataId': 'Q1262052'},
#                                                   {'confidenceScore': 2.045,
#                                                    'endingPos': 359,
#                                                    'entityEnglishId': 'Martyr',
#                                                    'entityId': 'Martyr',
#                                                    'freebaseId': '/m/0c_fp',
#                                                    'id': 20,
#                                                    'matchedText': 'martyr',
#                                                    'matchingTokens': [67],
#                                                    'relevanceScore': 0.09201,
#                                                    'startingPos': 353,
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Martyr',
#                                                    'wikidataId': 'Q6498826'},
#                                                   {'confidenceScore': 23.74,
#                                                    'endingPos': 253,
#                                                    'entityEnglishId': 'Saudi '
#                                                                       'Arabia',
#                                                    'entityId': 'Arabie '
#                                                                'saoudite',
#                                                    'freebaseId': '/m/01z215',
#                                                    'freebaseTypes': ['/government/government',
#                                                                      '/business/employer',
#                                                                      '/organization/organization_founder',
#                                                                      '/business/business_location',
#                                                                      '/location/location',
#                                                                      '/government/governmental_jurisdiction',
#                                                                      '/periodicals/newspaper_circulation_area',
#                                                                      '/location/dated_location',
#                                                                      '/organization/organization_scope',
#                                                                      '/olympics/olympic_participating_country',
#                                                                      '/military/military_post',
#                                                                      '/location/country',
#                                                                      '/location/statistical_region',
#                                                                      '/book/book_subject',
#                                                                      '/royalty/kingdom',
#                                                                      '/military/military_combatant',
#                                                                      '/sports/sports_team_location',
#                                                                      '/organization/organization_member',
#                                                                      '/symbols/flag_referent',
#                                                                      '/symbols/namesake'],
#                                                    'id': 21,
#                                                    'matchedText': 'Arabie '
#                                                                   'saoudite',
#                                                    'matchingTokens': [43, 44],
#                                                    'relevanceScore': 0.3095,
#                                                    'startingPos': 238,
#                                                    'type': ['Place',
#                                                             'PopulatedPlace',
#                                                             'Country'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Arabie_saoudite',
#                                                    'wikidataId': 'Q851'},
#                                                   {'confidenceScore': 2.066,
#                                                    'endingPos': 436,
#                                                    'entityEnglishId': "Lord's "
#                                                                       'Prayer',
#                                                    'entityId': 'Notre Père',
#                                                    'freebaseId': '/m/0h4b9',
#                                                    'freebaseTypes': ['/religion/prayer',
#                                                                      '/media_common/quotation_subject'],
#                                                    'id': 22,
#                                                    'matchedText': 'notre père',
#                                                    'matchingTokens': [80, 81],
#                                                    'relevanceScore': 0.137,
#                                                    'startingPos': 426,
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Notre_Père',
#                                                    'wikidataId': 'Q23393'},
#                                                   {'confidenceScore': 7.591,
#                                                    'crunchbaseId': 'twitter',
#                                                    'endingPos': 459,
#                                                    'entityEnglishId': 'Twitter',
#                                                    'entityId': 'Twitter',
#                                                    'freebaseId': '/m/0289n8t',
#                                                    'freebaseTypes': ['/media_common/quotation_source',
#                                                                      '/business/employer',
#                                                                      '/award/award_nominated_work',
#                                                                      '/book/book_subject',
#                                                                      '/media_common/quotation_subject',
#                                                                      '/organization/organization_partnership',
#                                                                      '/business/customer',
#                                                                      '/award/award_winning_work',
#                                                                      '/internet/website'],
#                                                    'id': 23,
#                                                    'lei': '549300I8RX485XMK6836',
#                                                    'matchedText': 'Twitter',
#                                                    'matchingTokens': [87],
#                                                    'permid': '4296301199',
#                                                    'relevanceScore': 0.2149,
#                                                    'startingPos': 452,
#                                                    'type': ['Agent',
#                                                             'Organisation',
#                                                             'Company'],
#                                                    'wikiLink': 'http://fr.wikipedia.org/wiki/Twitter',
# ...
#                                                           'religion',
#                                                  'score': 0.1218,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Psychology_of_religion',
#                                                  'wikidataId': 'Q368498'},
#                                                 {'id': 91,
#                                                  'label': 'Killings',
#                                                  'score': 0.1155,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Killings_by_type'},
#                                                 {'id': 92,
#                                                  'label': "Lord's Prayer",
#                                                  'score': 0.1141,
#                                                  'wikiLink': "http://en.wikipedia.org/Lord's_Prayer",
#                                                  'wikidataId': 'Q23393'},
#                                                 {'id': 93,
#                                                  'label': 'Politics of Asia',
#                                                  'score': 0.1125,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Politics_of_Asia',
#                                                  'wikidataId': 'Q3349297'},
#                                                 {'id': 94,
#                                                  'label': 'Nationalism',
#                                                  'score': 0.1084,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Nationalism',
#                                                  'wikidataId': 'Q6235'},
#                                                 {'id': 95,
#                                                  'label': 'Religion and '
#                                                           'politics',
#                                                  'score': 0.1015,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Religion_and_politics',
#                                                  'wikidataId': 'Q1526011'},
#                                                 {'id': 96,
#                                                  'label': 'National security',
#                                                  'score': 0.1002,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:National_security',
#                                                  'wikidataId': 'Q258307'},
#                                                 {'id': 97,
#                                                  'label': 'Social issues',
#                                                  'score': 0.09951,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Social_issues',
#                                                  'wikidataId': 'Q1920219'},
#                                                 {'id': 98,
#                                                  'label': 'Prayer',
#                                                  'score': 0.09845,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Prayer',
#                                                  'wikidataId': 'Q40953'},
#                                                 {'id': 99,
#                                                  'label': 'Cultural politics',
#                                                  'score': 0.0925,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Cultural_politics',
#                                                  'wikidataId': 'Q1711347'},
#                                                 {'id': 100,
#                                                  'label': 'Identity politics',
#                                                  'score': 0.09071,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Identity_politics',
#                                                  'wikidataId': 'Q2914650'},
#                                                 {'id': 101,
#                                                  'label': 'Sermon on the Mount',
#                                                  'score': 0.08953,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Sermon_on_the_Mount',
#                                                  'wikidataId': 'Q51640'},
#                                                 {'id': 102,
#                                                  'label': 'International '
#                                                           'relations',
#                                                  'score': 0.08946,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:International_relations',
#                                                  'wikidataId': 'Q166542'},
#                                                 {'id': 103,
#                                                  'label': 'Aftermath of the '
#                                                           'Arab Spring',
#                                                  'score': 0.08892,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Aftermath_of_the_Arab_Spring'},
#                                                 {'id': 104,
#                                                  'label': 'Politics of North '
#                                                           'Africa',
#                                                  'score': 0.08288,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Politics_of_North_Africa'},
#                                                 {'id': 105,
#                                                  'label': 'Justice',
#                                                  'score': 0.08182,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Justice',
#                                                  'wikidataId': 'Q5167661'},
#                                                 {'id': 106,
#                                                  'label': 'Christian prayer',
#                                                  'score': 0.08166,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Christian_prayer',
#                                                  'wikidataId': 'Q15079132'},
#                                                 {'id': 107,
#                                                  'label': 'Controversies',
#                                                  'score': 0.08044,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Controversies',
#                                                  'wikidataId': 'Q1255828'},
#                                                 {'id': 108,
#                                                  'label': 'Syrian Civil War',
#                                                  'score': 0.07978,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Syrian_Civil_War',
#                                                  'wikidataId': 'Q178810'},
#                                                 {'id': 109,
#                                                  'label': 'Sayings of Jesus',
#                                                  'score': 0.07464,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Sayings_of_Jesus',
#                                                  'wikidataId': 'Q1868072'},
#                                                 {'id': 110,
#                                                  'label': 'Roman Catholic '
#                                                           'prayers',
#                                                  'score': 0.06835,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Roman_Catholic_prayers',
#                                                  'wikidataId': 'Q3406098'},
#                                                 {'id': 111,
#                                                  'label': 'Warfare',
#                                                  'score': 0.06597,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Warfare',
#                                                  'wikidataId': 'Q12786121'},
#                                                 {'id': 112,
#                                                  'label': 'Homicide',
#                                                  'score': 0.06502,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Homicide',
#                                                  'wikidataId': 'Q149086'},
#                                                 {'id': 113,
#                                                  'label': 'Social institutions',
#                                                  'score': 0.06391,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Social_institutions',
#                                                  'wikidataId': 'Q178706'},
#                                                 {'id': 114,
#                                                  'label': 'Christian worship '
#                                                           'and liturgy',
#                                                  'score': 0.06265,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Christian_worship_and_liturgy',
#                                                  'wikidataId': 'Q1539016'},
#                                                 {'id': 115,
#                                                  'label': 'Criminal law',
#                                                  'score': 0.06264,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Criminal_law',
#                                                  'wikidataId': 'Q146491'},
#                                                 {'id': 116,
#                                                  'label': 'Political theories',
#                                                  'score': 0.06206,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Political_theories',
#                                                  'wikidataId': 'Q9357091'},
#                                                 {'id': 117,
#                                                  'label': 'Literature',
#                                                  'score': 0.06166,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Literature',
#                                                  'wikidataId': 'Q8242'},
#                                                 {'id': 118,
#                                                  'label': 'Pulitzer '
#                                                           'Prize-winning '
#                                                           'newspapers',
#                                                  'score': 0.06098,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Pulitzer_Prize-winning_newspapers'},
#                                                 {'id': 119,
#                                                  'label': 'Religious '
#                                                           'persecution',
#                                                  'score': 0.06057,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Religious_persecution',
#                                                  'wikidataId': 'Q301585'},
#                                                 {'id': 120,
#                                                  'label': 'Religion and '
#                                                           'government',
#                                                  'score': 0.05967,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Religion_and_government'},
#                                                 {'id': 121,
#                                                  'label': 'New Testament words '
#                                                           'and phrases',
#                                                  'score': 0.05746,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:New_Testament_words_and_phrases'},
#                                                 {'id': 122,
#                                                  'label': 'Law enforcement',
#                                                  'score': 0.05535,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Law_enforcement',
#                                                  'wikidataId': 'Q44554'},
#                                                 {'id': 123,
#                                                  'label': 'Social conflict',
#                                                  'score': 0.05412,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Social_conflict',
#                                                  'wikidataId': 'Q2672648'},
#                                                 {'id': 124,
#                                                  'label': 'Pulitzer Prize for '
#                                                           'National Reporting '
#                                                           'winners',
#                                                  'score': 0.05366,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Pulitzer_Prize_for_National_Reporting_winners'},
#                                                 {'id': 125,
#                                                  'label': 'Dissolution of '
#                                                           'Syria',
#                                                  'score': 0.05275,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Dissolution_of_Syria'},
#                                                 {'id': 126,
#                                                  'label': 'Quotations from '
#                                                           'religion',
#                                                  'score': 0.05271,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Quotations_from_religion'},
#                                                 {'id': 127,
#                                                  'label': 'Aggression',
#                                                  'score': 0.05225,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Aggression',
#                                                  'wikidataId': 'Q191797'},
#                                                 {'id': 128,
#                                                  'label': 'Arab Winter',
#                                                  'score': 0.05125,
#                                                  'wikiLink': 'http://en.wikipedia.org/Category:Arab_Winter',
#                                                  'wikidataId': 'Q17512479'}]},
#                         'time': 0.04505},
#  'title': 'La famille du journaliste saoudien tué dans le consul d’Arabie '
#           'saoudite à Istanbul «pardonne» aux assassins',
#  'url': 'https://plus.lesoir.be/302284/article/2020-05-22/la-famille-du-journaliste-saoudien-tue-dans-le-consul-darabie-saoudite-istanbul'}

# %%
x = mycol.find_one()

# %%
print(x['meta']['source'])

# %%
filter = {}

# %%
n_articles = mycol.count_documents(filter)

# %%
print(n_articles)

# %%
filter_fr = {
'meta.source.language': 'fr'}

# %%
filter_nl = {
'meta.source.language': 'nl'}

# %%
n_fr_articles = mycol.count_documents(filter_fr)

# %%
n_nl_articles = mycol.count_documents(filter_nl)

# %%
print(n_fr_articles)
print(n_nl_articles)

# %%
fr_articles = mycol.find(filter_fr, limit = 3)

# %%
fr_articles = mycol.find({
'meta.source.language': 'fr'})

# %%
fr_articles_agg = mycol.aggregate([{"$match": filter_fr}, {"$limit": 3}, {"$out":"fr_art3"}])

# %%
fr_articles_agg

# %%
for doc in fr_articles:
    print(type(doc))

# %%
import pandas as pd
import os

# %%
all_french = pd.read_csv('all_french_data.csv')

# %%
all_french.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   _id     966 non-null    object
#  1   url     966 non-null    object
#  2   title   966 non-null    object
#  3   date    966 non-null    object
#  4   text    956 non-null    object
# dtypes: object(5)
# memory usage: 37.9+ KB
